# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
# Mendefinisikan variabel z dari o sampai 20 
z= np.linspace(0, 20, 400)
# Menghitung nilai X(z)
X_z = (z*(z+1))/(z**2 - z + 0.5)
# Membuat plot
plt.figure(figsize=(10, 6))
plt.plot(z, X_z, label='$X(z) = \\frac{z(z+1)}{z^22+0.5}$')
plt.title('Grafik $X(z)$')
plt.xlabel('z')
plt.ylabel('$x(z)$')
plt.legend()
plt.grid(True)
plt.show()
